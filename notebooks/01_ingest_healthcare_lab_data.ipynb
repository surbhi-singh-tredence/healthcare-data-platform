# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload
# To disable autoreload; run %autoreload 0

# %%
from src.ingestion.bronze_loader import load_raw_csv, add_ingestion_metadata, write_bronze_table

# %%
INPUT_PATH = "/Volumes/healthcare/data/heathcare_lab_data/healthcare_lab_dataset.csv"

BRONZE_TABLE = "healthcare.bronze.healthcare_qa_raw"

df = load_raw_csv(spark,INPUT_PATH)

df = add_ingestion_metadata(df)

write_bronze_table(spark=spark,df=df, table_name=BRONZE_TABLE)

# %%
# %sql
SELECT COUNT(*) FROM healthcare.bronze.healthcare_qa_raw
